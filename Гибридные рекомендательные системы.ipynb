# %%
# !python3 --version
# Out:
# Python 3.10.18

# %%
conda install -c conda-forge lightfm
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/myenv
#
#   added / updated specs:
#     - lightfm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libgfortran-5.0.0          |14_2_0_h6c33f7e_103         153 KB  conda-forge
#     libgfortran5-14.2.0        |     h6c33f7e_103         788 KB  conda-forge
#     llvm-openmp-17.0.6         |       hcd81f8e_0         268 KB  conda-forge
#     urllib3-2.5.0              |     pyhd8ed1ab_0          99 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      conda-forge/osx-arm64::brotli-python-1.1.0-py310hb4ad77e_2
#   certifi            conda-forge/noarch::certifi-2025.6.15-pyhd8ed1ab_0
#   cffi               conda-forge/osx-arm64::cffi-1.17.1-py310h497396d_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.4.2-pyhd8ed1ab_0
#   h2                 conda-forge/noarch::h2-4.2.0-pyhd8ed1ab_0
#   hpack              conda-forge/noarch::hpack-4.1.0-pyhd8ed1ab_0
#   hyperframe         conda-forge/noarch::hyperframe-6.1.0-pyhd8ed1ab_0
#   idna               conda-forge/noarch::idna-3.10-pyhd8ed1ab_1
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-31_h10e41b3_openblas
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-31_hb3479ef_openblas
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-14_2_0_h6c33f7e_103
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-14.2.0-h6c33f7e_103
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-31_hc9a63f6_openblas
#   libopenblas        pkgs/main/osx-arm64::libopenblas-0.3.29-hea593b9_0
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.45.2-h091b4b1_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.3.1-h8359307_2
#   lightfm            conda-forge/osx-arm64::lightfm-1.17-py310hf1a086a_2
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-17.0.6-hcd81f8e_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   pycparser          conda-forge/noarch::pycparser-2.22-pyh29332c3_1
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha55dd90_7
#   python_abi         conda-forge/noarch::python_abi-3.10-7_cp310
#   requests           conda-forge/noarch::requests-2.32.4-pyhd8ed1ab_0
#   scipy              conda-forge/osx-arm64::scipy-1.14.1-py310hc05a576_1
#   urllib3            conda-forge/noarch::urllib3-2.5.0-pyhd8ed1ab_0
#   zstandard          conda-forge/osx-arm64::zstandard-0.23.0-py310h078409c_2
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-~ --> conda-forge/noarch::ca-certificates-2025.6.15-hbd8a1cb_0
#   openssl              pkgs/main::openssl-3.0.16-h02f6b3c_0 --> conda-forge::openssl-3.5.0-h81ee809_1
#   zlib                    pkgs/main::zlib-1.2.13-h18a0788_1 --> conda-forge::zlib-1.3.1-h8359307_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   python               pkgs/main::python-3.10.18-h19e8193_0 --> conda-forge::python-3.10.13-h2469fbe_1_cpython
#   sqlite                pkgs/main::sqlite-3.45.3-h80987f9_0 --> conda-forge::sqlite-3.45.2-hf2abe2d_0
#   tk                        pkgs/main::tk-8.6.14-h6ba3021_1 --> conda-forge::tk-8.6.13-h892fb3f_2
#
#
#
# Downloading and Extracting Packages:
# libgfortran5-14.2.0  | 788 KB    |                                       |   0%
# llvm-openmp-17.0.6   | 268 KB    |                                       |   0%
#
# libgfortran-5.0.0    | 153 KB    |                                       |   0%
#
#
# urllib3-2.5.0        | 99 KB     |                                       |   0%
#
# libgfortran-5.0.0    | 153 KB    | ###8                                  |  10%
#
# libgfortran5-14.2.0  | 788 KB    | 7                                     |   2%
#
# libgfortran5-14.2.0  | 788 KB    | #############5                        |  37%
# libgfortran5-14.2.0  | 788 KB    | ##############################8       |  83%
# libgfortran5-14.2.0  | 788 KB    | ##################################### | 100%
#
#
# urllib3-2.5.0        | 99 KB     | #####9                                |  16%
# llvm-openmp-17.0.6   | 268 KB    | ##################################### | 100%
#
#
# urllib3-2.5.0        | 99 KB     | ##################################### | 100%
# llvm-openmp-17.0.6   | 268 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from lightfm import LightFM
from lightfm.datasets import fetch_movielens
from lightfm.evaluation import auc_score
from lightfm.evaluation import precision_at_k
from lightfm.datasets import fetch_movielens
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.10/site-packages/lightfm/_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.0-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# Successfully installed pandas-2.3.0 pytz-2025.2 tzdata-2025.2

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (1.26.4)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.4-cp310-cp310-macosx_10_9_universal2.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp310-cp310-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 4.3 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.4-cp310-cp310-macosx_10_9_universal2.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
# Downloading pillow-11.2.1-cp310-cp310-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.4 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3

# %%
# !pip install flask
# Out:
# Collecting flask
#   Downloading flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting blinker>=1.9.0 (from flask)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from flask)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting itsdangerous>=2.2.0 (from flask)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/myenv/lib/python3.10/site-packages (from flask) (3.0.2)
# Collecting werkzeug>=3.1.0 (from flask)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Downloading flask-3.1.1-py3-none-any.whl (103 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: werkzeug, itsdangerous, click, blinker, flask
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [flask]
# Successfully installed blinker-1.9.0 click-8.2.1 flask-3.1.1 itsdangerous-2.2.0 werkzeug-3.1.3
