# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "https://books.toscrape.com/catalogue/"

def parse_book_details(book_url):
    response = requests.get(book_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    upc = soup.find('table', class_='table').find_all('tr')[0].find_all('td')[0].text
    return upc
    
def parse_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    books = []
    for book in soup.find_all('article', class_='product_pod'):
        book_name = book.h3.a['title']
        price = book.find('p', class_='price_color').text[1:]
        book_url = BASE_URL + book.h3.a['href']
        
        book_upc = parse_book_details(book_url)
        books.append({
            'id': book_upc,
            'book_name': book_name,
            'price': price,
            'url': book_url
        })
        return books
        
def scrape_books(max_books=1000):
    all_books = []
    page = 1
    while len(all_books) < max_books:
        url = f"https://books.toscrape.com/catalogue/page-{page}.html"
        books = parse_page(url)
        if not books:
            break
        all_books.extend(books)
        page += 1
    return all_books[:max_books]
    
books_data = scrape_books()

df = pd.DataFrame(books_data)

df.to_csv('books.csv', index=False)

print("Файл books.csv создан!")
# Out:
# Файл books.csv создан!

# %%
df.head(300)
# Out:
#                   id                                          book_name  \
# 0   a897fe39b1053632                               A Light in the Attic
# 1   23356462d1320d61                                        In Her Wake
# 2   b4fd5943413e089a                     Slow States of Collapse: Poems
# 3   7d385d34d12e60ff           The Nameless City (The Nameless City #1)
# 4   0fa6dceead7ce47a  Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Pr...
# 5   e4f74c16de34d440  Immunity: How Elie Metchnikoff Changed the Cou...
# 6   38d45839cb1c83c1  Algorithms to Live By: The Computer Science of...
# 7   d6361d16212664ed                  The Shadow Hero (The Shadow Hero)
# 8   efc3768127714ec3  The Bridge to Consciousness: I'm Writing the B...
# 9   caf4fe9311f1dc59                                     Modern Romance
# 10  88c21fcd38e2486e                                         Dark Notes
# 11  44a10f1ac8ce822e  Whole Lotta Creativity Going On: 60 Fun and Un...
# 12  6bdd909329435e80  The Power of Habit: Why We Do What We Do in Li...
# 13  4c8b7540409da4ac                             Swell: A Year of Waves
# 14  727bf2b86b19ad88                             My Name Is Lucy Barton
# 15  0b165bd4b9f42fd5            Hold Your Breath (Search and Rescue #1)
# 16  33a3e0e3ffde0dcd             Code Name Verity (Code Name Verity #1)
# 17  39861fc1c0845d15                        All the Light We Cannot See
# 18  14e44163678e24dc  The Midnight Watch: A Novel of the Titanic and...
# 19  bddc6fd036eb6279                         Hide Away (Eve Duncan #20)
# 20  47e1b2d43f709995                                   Mothering Sunday
# 21  ab60e6f5a63e1cfb                                      Without Shame
# 22  7186241e043de5dc  Chernobyl 01:23:40: The Incredible True Story ...
# 23  aeb51dfbe8aeec59                                        Roller Girl
# 24  d48c1369927ebef1  Heaven is for Real: A Little Boy's Astounding ...
# 25  9147c5251cc99eb1                                   The Story of Art
# 26  746029796363aa51                               Nightstruck: A Novel
# 27  5b546a46a86a9d8c                Benjamin Franklin: An American Life
# 28  6478ccb4416e6a5d                     The Barefoot Contessa Cookbook
# 29  2e5b4ff08a75fd02    World Without End (The Pillars of the Earth #2)
# 30  fec06f52054ea900             The Dream Thieves (The Raven Cycle #2)
# 31  45045146dbf7b009  Isla and the Happily Ever After (Anna and the ...
# 32  d9290e99f189ce84                Alight (The Generations Trilogy #2)
# 33  38199c5d7da0c0ef           Shopaholic Ties the Knot (Shopaholic #3)
# 34  ad15a9a139919918           Far From True (Promise Falls Trilogy #2)
# 35  0e4e2d31c2fb3aad                    Walk the Edge (Thunder Road #2)
# 36  f06039c29b5891fa                  The Silkworm (Cormoran Strike #2)
# 37  70c7c3ca7f9b2728  The Lean Startup: How Today's Entrepreneurs Us...
# 38  dabf11918b48b40c              The Da Vinci Code (Robert Langdon #2)
